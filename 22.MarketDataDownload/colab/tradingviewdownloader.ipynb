# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
# Out:
# ...
#   Cloning https://github.com/rongardF/tvdatafeed.git to /tmp/pip-req-build-7afd1aqx
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed.git /tmp/pip-req-build-7afd1aqx
#   Resolved https://github.com/rongardF/tvdatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=88ec84b065f020b7db31e14446c5a983eaef9c66b2f4ebe31169d6bcf60fefda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c9mzuhj8/wheels/4b/f9/e9/82474a5d9a64702ba7dd5481dee05d267c69bcfa480d382b7c
# Successfully built tvdatafeed
# ...

# %%
from tvDatafeed import TvDatafeed, Interval

# %%
TICKER = 'SPX'
MARKET = 'CBOE'
FILENAME_FORMAT = '{}_{}_{}.csv'

# %%
tv = TvDatafeed()

df = tv.get_hist(symbol=TICKER,exchange=MARKET,interval=Interval.in_1_minute,n_bars=5000, extended_session=False)
df = df.reset_index()
df = df[['datetime','open','high','low','close','volume']]
df.columns = ['Time','Open','High','Low','Last','Volume']
df = df.sort_values(by=['Time'])
min_date = df['Time'].min().strftime('%Y-%m-%d')
max_date = df['Time'].max().strftime('%Y-%m-%d')
df['Time'] = df['Time'].dt.tz_localize('UTC').dt.tz_convert('US/Eastern').dt.strftime('%m/%d/%Y %H:%M')

filename = FILENAME_FORMAT.format(TICKER.lower(),min_date, max_date)
df.to_csv(filename, index=False)
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
df
# Out:
#                   Time     Open     High      Low     Last  Volume
# 0     04/05/2024 12:21  5215.88  5215.88  5213.50  5213.60     0.0
# 1     04/05/2024 12:22  5213.58  5214.01  5213.49  5213.90     0.0
# 2     04/05/2024 12:23  5214.02  5215.80  5214.02  5215.69     0.0
# 3     04/05/2024 12:24  5215.72  5217.69  5215.43  5217.69     0.0
# 4     04/05/2024 12:25  5217.61  5217.68  5214.83  5215.00     0.0
# ...                ...      ...      ...      ...      ...     ...
# 4995  04/24/2024 10:30  5078.42  5079.76  5078.38  5078.81     0.0
# 4996  04/24/2024 10:31  5078.77  5080.19  5078.72  5079.51     0.0
# 4997  04/24/2024 10:32  5079.46  5079.62  5078.48  5079.07     0.0
# 4998  04/24/2024 10:33  5079.02  5079.68  5077.27  5077.32     0.0
# 4999  04/24/2024 10:34  5077.28  5077.28  5075.22  5075.82     0.0
#
# [5000 rows x 6 columns]
